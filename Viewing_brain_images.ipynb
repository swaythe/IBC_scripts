# %%
from nilearn import plotting
# Out:
# /volatile/sshankar/pyp_env/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
import os

# %%
os.chdir('/volatile/sshankar/ds000003-00001/sub-01/anat/')

# %%
anat_01 = image.load_img('sub-01_T1w.nii.gz')

# %%
print(anat_01.header)

# %%
t2_01 = image.load_img('sub-01_inplaneT2.nii.gz')

# %%
print(t2_01.header)

# %%
plotting.view_img('sub-01_T1w.nii.gz')
# Out:
# /volatile/sshankar/pyp_env/lib/python3.6/site-packages/nilearn/image/resampling.py:510: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...

# %%
plotting.plot_anat('sub-01_T1w.nii.gz', cmap=plotting.cm.black_green)

# %%
plotting.view_img('sub-01_inplaneT2.nii.gz')
# Out:
# /volatile/sshankar/pyp_env/lib/python3.6/site-packages/nilearn/image/resampling.py:510: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...

# %%
plotting.plot_anat('sub-01_inplaneT2.nii.gz', cmap=plotting.cm.black_green)

# %%
os.chdir('/volatile/sshankar/ds000003-00001/sub-01/func/')

# %%
epi_fn = 'sub-01_task-rhymejudgment_bold.nii.gz'

# %%
from nilearn import image
# Out:
# /volatile/sshankar/pyp_env/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
epi_01 = image.load_img('sub-01_task-rhymejudgment_bold.nii.gz')

# %%
print(epi_01.header)

# %%
print(epi_01.shape)
# Out:
# (64, 64, 33, 160)

# %%
plotting.plot_epi(epi_01.slicer[...,30], cmap=)

# %%
epi_hd = image.load_img

# %%
plotting.plot_epi?
