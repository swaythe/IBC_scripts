# %%
from nilearn.input_data import NiftiMasker, MultiNiftiMasker
from nilearn.datasets import fetch_atlas_basc_multiscale_2015
from nilearn.image import new_img_like
from fastsrm.fastsrm import FastSRM
from nilearn import image, plotting
from shutil import copyfile
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import os
import glob
import ibc_public

# %matplotlib inline
# Out:
# /home/sshankar/env/fastsrm/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Specify the mask image
_package_directory = os.path.dirname(os.path.abspath(ibc_public.__file__))
mask_gm = nib.load(os.path.join(_package_directory, '../ibc_data', 'gm_mask_3mm.nii.gz'))

# %%
# Task of interest
task = 'audio'

# Any specific files that should be used for FastSRM
if task == 'clips':
    sessn = 3
    filepattern = '*Trn*.nii.gz'
else:
    sessn = 2
    filepattern = '*.nii.gz'

# %%
# Do this for a previously unused atlas. 
# Else, you should have a .npy file saved from before, and you can just load it.
# The transform() funtion takes a few minutes to run so don't run it 
# unless you absolutely need to.

# Now, a bit of shape shifting to make the atlas compatible with
# what fastsrm.reduce_data() requires.
# 1. Add a 4th dimension to the 3D atlas. The 4th dimension will have as many
#   elements as atlas parcesl (444, in this case)
# 2. The 3D "volume" pertaining to each 4th dimension will contain 1 in the
#   "voxel" for that parcel and 0 otherwise
# 3. Apply the atlas masker set up previously to transform the new 4D atlas
#   into 2D, with n_voxel rows and n_parcel columns,
#   where n_voxel is the number of voxels in the transformed image matrix
# 4. Reduce the 2D atlas matrix to 1D by using the argmax function along the
#   column dimension. Now, the transformed atlas has n_voxel elements.

atlas_loc = os.path.join('..', task, '3mm')
if os.path.exists(os.path.join(atlas_loc, 'atlas_masked.npy')):
    atlas = np.load(os.path.join(atlas_loc, 'atlas_masked.npy'), allow_pickle=True)
else:
    # Specify the atlas
    basc444 = fetch_atlas_basc_multiscale_2015()['scale444']
    basc_im = image.load_img(basc444).get_data()

    atlas_masker = NiftiMasker(mask_img=mask_gm).fit()

    if len(basc_im.shape) == 3:
        n_components = len(np.unique(basc_im)) - 1
        xa, ya, za = basc_im.shape
        A = np.zeros((xa, ya, za, n_components + 1))
        atlas = np.zeros((xa, ya, za, n_components + 1))
        for c in np.unique(basc_im)[1:].astype(int):
            X_ = np.copy(basc_im)
            X_[X_ != c] = 0.
            X_[X_ == c] = 1.
            A[:, :, :, c] = X_
        atlas = atlas_masker.transform(new_img_like(basc444, A))
        atlas = np.argmax(atlas, axis=0)

    # # Save the transformed atlas
    np.save(os.path.join(atlas_loc, 'atlas_masked.npy'), atlas)

# %%
# Create a masker to standardize (0 mean, 1 SD) the image files
# and to transform them to a 2D array, as FastSRM requires
img_masker = MultiNiftiMasker(mask_img=mask_gm, 
                              standardize=True, 
                              smoothing_fwhm=5,
                              detrend=True,
                              high_pass=1./128,
                              t_r=2.0).fit()

# %%
# Now create a list of movie session files 
movie_dir = os.path.join('..', task, '3mm/')
subs = sorted(glob.glob(movie_dir + 'sub*'))
nsub = 0

movie_arrays = []

# Number of sessions per subject
# Different tasks have different numbers of sessions.
# Also, all subjects might not have completed all sessions.
if task == 'clips':
    # For the clips task, one subject doesn't have all 4 sessions, and
    # FastSRM requires that all subjects have the same numbers of TRs
    sessn = 3
else:
    sessn = 2

# Create 2D masked arrays from image data and save to file for quick and easy access
for s, sub in enumerate(subs):
    if os.path.isdir(sub):
        nsub += 1
        sess = sorted(glob.glob(sub + '/ses*'))
       
        for i, ses in enumerate(sess):
            if os.path.isdir(ses) and i < sessn:
                if os.path.exists(os.path.join(ses,'masked_imgs_preproc.npy')):
                    masked_imgs = np.load(os.path.join(ses, 'masked_imgs_preproc.npy'), 
                                          allow_pickle=True)
                else:    
                    movie_imgs = sorted(glob.glob(ses + '/' + filepattern))
                    masked_imgs = img_masker.transform(movie_imgs)
                    np.save(os.path.join(ses, 'masked_imgs_preproc.npy'), masked_imgs)

                movie_arrays.append(masked_imgs)

# %%
# Now create a list of movie session files 
movie_dir = os.path.join('..', 'raiders', '3mm/')
subs = sorted(glob.glob(movie_dir + 'sub*'))

# Create 2D masked arrays from image data and save to file for quick and easy access
for s, sub in enumerate(subs):
    sess = sorted(glob.glob(sub + '/ses*'))

    for i, ses in enumerate(sess):
        movie_imgs = sorted(glob.glob(ses + '/' + filepattern))
        for i, mo in enumerate(movie_imgs):
            print(mo)
        print('\n')
# Out:
# ../raiders/3mm/sub-01/ses-01/wrdcsub-01_ses-16_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-01/ses-01/wrdcsub-01_ses-16_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-01/ses-01/wrdcsub-01_ses-16_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-01/ses-01/wrdcsub-01_ses-16_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-01/ses-01/wrdcsub-01_ses-16_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-01/ses-01/wrdcsub-01_ses-16_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-01/ses-02/wrdcsub-01_ses-17_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-01/ses-02/wrdcsub-01_ses-17_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-01/ses-02/wrdcsub-01_ses-17_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-01/ses-02/wrdcsub-01_ses-17_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-01/ses-02/wrdcsub-01_ses-17_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-01/ses-02/wrdcsub-01_ses-17_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-04/ses-01/wrdcsub-04_ses-13_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-04/ses-01/wrdcsub-04_ses-13_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-04/ses-01/wrdcsub-04_ses-13_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-04/ses-01/wrdcsub-04_ses-13_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-04/ses-01/wrdcsub-04_ses-13_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-04/ses-01/wrdcsub-04_ses-13_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-04/ses-02/wrdcsub-04_ses-14_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-04/ses-02/wrdcsub-04_ses-14_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-04/ses-02/wrdcsub-04_ses-14_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-04/ses-02/wrdcsub-04_ses-14_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-04/ses-02/wrdcsub-04_ses-14_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-04/ses-02/wrdcsub-04_ses-14_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-05/ses-01/wrdcsub-05_ses-13_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-05/ses-01/wrdcsub-05_ses-13_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-05/ses-01/wrdcsub-05_ses-13_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-05/ses-01/wrdcsub-05_ses-13_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-05/ses-01/wrdcsub-05_ses-13_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-05/ses-01/wrdcsub-05_ses-13_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-05/ses-02/wrdcsub-05_ses-14_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-05/ses-02/wrdcsub-05_ses-14_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-05/ses-02/wrdcsub-05_ses-14_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-05/ses-02/wrdcsub-05_ses-14_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-05/ses-02/wrdcsub-05_ses-14_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-05/ses-02/wrdcsub-05_ses-14_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-06/ses-01/wrdcsub-06_ses-13_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-06/ses-01/wrdcsub-06_ses-13_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-06/ses-01/wrdcsub-06_ses-13_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-06/ses-01/wrdcsub-06_ses-13_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-06/ses-01/wrdcsub-06_ses-13_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-06/ses-01/wrdcsub-06_ses-13_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-06/ses-02/wrdcsub-06_ses-14_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-06/ses-02/wrdcsub-06_ses-14_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-06/ses-02/wrdcsub-06_ses-14_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-06/ses-02/wrdcsub-06_ses-14_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-06/ses-02/wrdcsub-06_ses-14_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-06/ses-02/wrdcsub-06_ses-14_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-07/ses-01/wrdcsub-07_ses-14_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-07/ses-01/wrdcsub-07_ses-14_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-07/ses-01/wrdcsub-07_ses-14_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-07/ses-01/wrdcsub-07_ses-14_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-07/ses-01/wrdcsub-07_ses-14_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-07/ses-01/wrdcsub-07_ses-14_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-07/ses-02/wrdcsub-07_ses-15_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-07/ses-02/wrdcsub-07_ses-15_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-07/ses-02/wrdcsub-07_ses-15_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-07/ses-02/wrdcsub-07_ses-15_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-07/ses-02/wrdcsub-07_ses-15_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-07/ses-02/wrdcsub-07_ses-15_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-09/ses-01/wrdcsub-09_ses-14_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-09/ses-01/wrdcsub-09_ses-14_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-09/ses-01/wrdcsub-09_ses-14_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-09/ses-01/wrdcsub-09_ses-14_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-09/ses-01/wrdcsub-09_ses-14_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-09/ses-01/wrdcsub-09_ses-14_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-09/ses-02/wrdcsub-09_ses-15_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-09/ses-02/wrdcsub-09_ses-15_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-09/ses-02/wrdcsub-09_ses-15_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-09/ses-02/wrdcsub-09_ses-15_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-09/ses-02/wrdcsub-09_ses-15_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-09/ses-02/wrdcsub-09_ses-15_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-11/ses-01/wrdcsub-11_ses-14_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-11/ses-01/wrdcsub-11_ses-14_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-11/ses-01/wrdcsub-11_ses-14_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-11/ses-01/wrdcsub-11_ses-14_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-11/ses-01/wrdcsub-11_ses-14_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-11/ses-01/wrdcsub-11_ses-14_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-11/ses-02/wrdcsub-11_ses-15_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-11/ses-02/wrdcsub-11_ses-15_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-11/ses-02/wrdcsub-11_ses-15_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-11/ses-02/wrdcsub-11_ses-15_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-11/ses-02/wrdcsub-11_ses-15_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-11/ses-02/wrdcsub-11_ses-15_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-12/ses-01/wrdcsub-12_ses-14_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-12/ses-01/wrdcsub-12_ses-14_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-12/ses-01/wrdcsub-12_ses-14_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-12/ses-01/wrdcsub-12_ses-14_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-12/ses-01/wrdcsub-12_ses-14_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-12/ses-01/wrdcsub-12_ses-14_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-12/ses-02/wrdcsub-12_ses-15_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-12/ses-02/wrdcsub-12_ses-15_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-12/ses-02/wrdcsub-12_ses-15_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-12/ses-02/wrdcsub-12_ses-15_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-12/ses-02/wrdcsub-12_ses-15_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-12/ses-02/wrdcsub-12_ses-15_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-13/ses-01/wrdcsub-13_ses-13_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-13/ses-01/wrdcsub-13_ses-13_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-13/ses-01/wrdcsub-13_ses-13_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-13/ses-01/wrdcsub-13_ses-13_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-13/ses-01/wrdcsub-13_ses-13_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-13/ses-01/wrdcsub-13_ses-13_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-13/ses-02/wrdcsub-13_ses-14_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-13/ses-02/wrdcsub-13_ses-14_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-13/ses-02/wrdcsub-13_ses-14_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-13/ses-02/wrdcsub-13_ses-14_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-13/ses-02/wrdcsub-13_ses-14_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-13/ses-02/wrdcsub-13_ses-14_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-14/ses-01/wrdcsub-14_ses-14_task-Raiders_acq-ap_run-04_bold.nii.gz
# ../raiders/3mm/sub-14/ses-01/wrdcsub-14_ses-14_task-Raiders_acq-ap_run-05_bold.nii.gz
# ../raiders/3mm/sub-14/ses-01/wrdcsub-14_ses-14_task-Raiders_acq-ap_run-06_bold.nii.gz
# ../raiders/3mm/sub-14/ses-01/wrdcsub-14_ses-14_task-Raiders_acq-pa_run-01_bold.nii.gz
# ../raiders/3mm/sub-14/ses-01/wrdcsub-14_ses-14_task-Raiders_acq-pa_run-02_bold.nii.gz
# ../raiders/3mm/sub-14/ses-01/wrdcsub-14_ses-14_task-Raiders_acq-pa_run-03_bold.nii.gz
# ]
#
# ../raiders/3mm/sub-14/ses-02/wrdcsub-14_ses-15_task-Raiders_acq-ap_run-09_bold.nii.gz
# ../raiders/3mm/sub-14/ses-02/wrdcsub-14_ses-15_task-Raiders_acq-ap_run-10_bold.nii.gz
# ../raiders/3mm/sub-14/ses-02/wrdcsub-14_ses-15_task-Raiders_acq-ap_run-11_bold.nii.gz
# ../raiders/3mm/sub-14/ses-02/wrdcsub-14_ses-15_task-Raiders_acq-ap_run-12_bold.nii.gz
# ../raiders/3mm/sub-14/ses-02/wrdcsub-14_ses-15_task-Raiders_acq-pa_run-07_bold.nii.gz
# ../raiders/3mm/sub-14/ses-02/wrdcsub-14_ses-15_task-Raiders_acq-pa_run-08_bold.nii.gz
# ]

# %%
nsess = sidx

# %%
nsub

# %%
for i in range(nsub):
    for j in range(len(movie_arrays[i])):
        print(movie_arrays[i][j].shape)
# movie_arrays[0][1].shape

# %%
len(movie_arrays[0])

# %%
# Concatenate all the runs belonging to each subject, 
# and then create a list of lists with all subjects' data
sub_movie = []
# nsess = len(movie_arrays[0])
for i in range(0, nsub*sessn, sessn):
    part = []
    for j in range(sessn):
        # The inner concatenates create one list each for each session
        # The outer concatenate creates one list with data from all runs
        part.append(np.concatenate(movie_arrays[i+j]))
    sub_movie.append(np.concatenate(part).T)
#         sub_movie.append(np.concatenate((np.concatenate(movie_arrays[i]), np.concatenate(movie_arrays[i+1]))).T)

# %%
for i in range(nsub):
    print(sub_movie[i].shape)
# Out:
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)
# (46448, 2328)

# %%
# Fit the FastSRM model with the data
fast_srm = FastSRM(
    atlas=atlas,
    n_components=20,
    n_jobs=1,
    n_iter=10,
    temp_dir='/tmp',
    low_ram=True, 
    aggregate="mean",
)
fast_srm.fit(sub_movie)
# Out:
# FastSRM(aggregate='mean', atlas=array([333, 333, 190, ..., 112, 315, 315]),
#         low_ram=True, n_components=20, n_iter=10, n_jobs=1,
#         temp_dir='/tmp/fastsrma993d7c7-0380-4cf5-ad49-aaecded42f5e',
#         verbose='warn')

# %%
# Compute the shared temporal responses of subjects while watching the movie
shared_resp = fast_srm.transform(sub_movie)

# %%
shared_resp.shape
# Out:
# (20, 2328)

# %%
# Save the shared response vector for future use
fastsrm_dir = os.path.join(movie_dir, 'fastsrm')
if not os.path.isdir(fastsrm_dir):
    os.mkdir(fastsrm_dir)

np.save(os.path.join(fastsrm_dir, 'shared_resp.npy'), shared_resp)

# %%
# These are what the shared responses look like
fig, axs = plt.subplots(20, sharex=True, sharey=True, 
                        figsize=(10,50))
# gridspec_kw={'hspace': 0.2}
for i in range(len(shared_resp)):
    axs[i].plot(shared_resp[i,:])
    axs[i].set_title('Shared response #' + str(i+1))

# %%
fig.savefig(os.path.join(fastsrm_dir, 'shared_resp.pdf'), format='pdf', transparent=False)

# %%
# These are what the spatial maps look like, for one subject
bl1 = np.load('/tmp/fastsrm7cb4ce8e-1d76-4615-9c17-5a3cf6c57b16/basis_9.npy', allow_pickle=True)
inv_mask_bl1 = img_masker.inverse_transform(bl1)

for i in range(len(shared_resp)):
    plotting.plot_epi(inv_mask_bl1.slicer[...,i], draw_cross=False, 
                     cut_coords=7, display_mode='z', black_bg=True, cmap=plotting.cm.blue_red)

# %%
# These are what the spatial maps look like, for a different subject
bl1 = np.load('/tmp/fastsrm7cb4ce8e-1d76-4615-9c17-5a3cf6c57b16/basis_5.npy', allow_pickle=True)
inv_mask_bl1 = img_masker.inverse_transform(bl1)

for i in range(len(shared_resp)):
    plotting.plot_epi(inv_mask_bl1.slicer[...,i], draw_cross=False, 
                     cut_coords=7, display_mode='z', black_bg=True, cmap=plotting.cm.blue_red)

# %%
# The subject-specific spatial maps are in the parameter basis_list
# These spatial maps have been created using all runs from all subjects
fast_srm.basis_list

# %%
# Save the basis lists to subject folders for posterity
subs = sorted(glob.glob(movie_dir + 'sub*'))

for s, sub in enumerate(subs):
    srm_sub_dir = os.path.join(sub, 'fastsrm')
    if not os.path.isdir(srm_sub_dir):
        os.mkdir(srm_sub_dir)
    copyfile(fast_srm.basis_list[s], os.path.join(srm_sub_dir, 'basis_list.npy'))

# %%
# Split the basis lists into their components and save them as 
# niimg-like files to use in other nistats/nilearn functions
subs = sorted(glob.glob(movie_dir + 'sub*'))

for s, sub in enumerate(subs):
    bls = np.load(os.path.join(sub, 'fastsrm', 'basis_list.npy'))
    for i in range(20):
        nib.save(img_masker.inverse_transform(bls[i]), 
                 os.path.join(sub, 'fastsrm', 'basis_list-' + str(i).zfill(2) + '.nii.gz'))

# %% [markdown]
# On to second level model

# %%
# Import the necessary modules/functions
import pandas as pd
import numpy as np
from nistats.second_level_model import SecondLevelModel
from nistats.thresholding import map_threshold
from nilearn import plotting
from nistats.reporting import make_glm_report

# %%
# Let's gather the files that will form the input to the second level analysis
n_components = 20
second_level_input = np.empty((nsub,n_components), dtype='object')
subs = sorted(glob.glob(movie_dir + 'sub*'))

for s, sub in enumerate(subs):
    for c in range(n_components):
        second_level_input[s][c] = os.path.join(
            sub, 'fastsrm', 'basis_list-' + str(c).zfill(2) + '.nii.gz')

# %%
second_level_input

# %%
# Construct a design matrix. We are including all subjects and 
# essentially finding the "main effects" of the contrasts performed
# in the first level analysis
design_matrix = pd.DataFrame([1] * len(second_level_input), columns=['intercept'])

# %%
# Set up the second level analysis
second_level_model = SecondLevelModel(smoothing_fwhm=8)

# %%
# Compute the contrast/main effect
for i in range(20):
    z_map = second_level_model.fit(list(second_level_input[:,i]), 
                                    design_matrix=design_matrix).compute_contrast(output_type='z_score')
    report = make_glm_report(second_level_model, 'intercept')
    report.save_as_html(os.path.join(movie_dir, 'fastsrm_temp', 'component-' + str(i).zfill(2) + '.html'))

# %%
os.getcwd()

# %%
# Some FPR correction with cluster size thresholding, after applying an uncorrected p=0.01
thresholded_map1, threshold1 = map_threshold(z_map1, alpha=.01, height_control='fpr', cluster_threshold=0)

# %% [markdown]
# Let's do the temporal ICA on the shared responses here
# since we need to use the inverse transform function

# %%
from sklearn.decomposition import FastICA

# Set up some parameters for the ICA
n_components = 20
random_state = 0
max_iter = 5000
tol = 0.005

# Initialize the ICA model
fast_ica = FastICA(n_components=n_components,
                  random_state=random_state,
                  max_iter=max_iter,
                  tol=tol)

# Transform input data using the ICA model
shared_resp_ica = fast_ica.fit_transform(shared_resp.T).T

# %%
# Use the add_subjects() function to generate spatial maps
# corresponding to the ICA components
fast_srm.add_subjects(sub_movie, shared_resp_ica)

# %%
fast_srm.basis_list

# %%
# Save the basis lists to subject folders for posterity
from shutil import copyfile

subs = sorted(glob.glob(movie_dir + '/sub*'))

sidx = 10
for s, sub in enumerate(subs):
    if os.path.isdir(sub):
        copyfile(fast_srm.basis_list[sidx], 
                 os.path.join(sub, 'fastsrm', 'tica_on_fastsrm', 'tica_basis_list.npy'))
        sidx += 1

# %%
# Split the basis lists into their components and save them as 
# niimg-like files to use in other nistats/nilearn functions
subs = sorted(glob.glob(movie_dir + '/sub*'))

for s, sub in enumerate(subs):
    if os.path.isdir(sub):
        bls = np.load(os.path.join(sub, 'fastsrm', 'tica_on_fastsrm', 'tica_basis_list.npy'))
        for i in range(20):
            nib.save(img_masker.inverse_transform(bls[i]), 
                     os.path.join(sub, 'fastsrm', 'tica_on_fastsrm', 
                                  'tica_basis_list-' + str(i).zfill(2) + '.nii.gz'))

# %% [markdown]
# Second level maps from tICA components

# %%
# Import the necessary modules/functions
import pandas as pd
import numpy as np
from nistats.second_level_model import SecondLevelModel
from nistats.thresholding import map_threshold
from nilearn import plotting
from nistats.reporting import make_glm_report

task = 'clips'
movie_dir = os.path.join('..', task, '3mm')
subs = sorted(glob.glob(movie_dir + '/sub*'))
nsub = len(subs)

# Let's gather the files that will form the input to the second level analysis
n_components = 20
second_level_input = np.empty((nsub,n_components), dtype='object')

sidx = 0
for s, sub in enumerate(subs):
    if os.path.isdir(sub):
        for c in range(n_components):
            second_level_input[sidx][c] = os.path.join(sub, 'fastsrm', 'tica_on_fastsrm', 
                                                       'tica_basis_list-' + str(c) + '.nii.gz')
        sidx += 1

# Construct a design matrix. We are including all subjects and 
# essentially finding the "main effects" of the contrasts performed
# in the first level analysis
design_matrix = pd.DataFrame([1] * len(second_level_input), columns=['intercept'])

# Set up the second level analysis
second_level_model = SecondLevelModel(smoothing_fwhm=8)

# Compute the contrast/main effect
for i in range(20):
    z_map = second_level_model.fit(list(second_level_input[:,i]), 
                                    design_matrix=design_matrix).compute_contrast(output_type='z_score')
    report = make_glm_report(second_level_model, 'intercept')
    report.save_as_html(os.path.join(movie_dir, 'fastsrm', 'tica_on_fastsrm', 
                                     'component-' + str(i).zfill(2) + '.html'))

# %%
# Some FPR correction with cluster size thresholding, after applying an uncorrected p=0.01
thresholded_map1, threshold1 = map_threshold(z_map1, alpha=.01, height_control='fpr', cluster_threshold=0)
