# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %matplotlib inline

# %%
# Task of interest
task = 'raiders'

# %%
# Load the confound files

# Computed from raw data
raw_conf = []
confound_pattern = '*confound*.npy'

raw_conf_files = '/home/sshankar/raiders/derivatives/confounds/raw_data/sub-01/ses-16/'
files = sorted(glob.glob(raw_conf_files + confound_pattern))
for fi, file in enumerate(files):
    raw_conf.append(np.load(file, allow_pickle=True))
    
raw_conf_files = '/home/sshankar/raiders/derivatives/confounds/raw_data/sub-01/ses-17/'
files = sorted(glob.glob(raw_conf_files + confound_pattern))
for fi, file in enumerate(files):
    raw_conf.append(np.load(file, allow_pickle=True))

# %%
# Computed from preprocessed data
preproc_conf_files = '/home/sshankar/raiders/derivatives/sub-01/ses-16/'
preproc_conf = []
confound_pattern = '*confound*.npy'

files = sorted(glob.glob(preproc_conf_files + confound_pattern))
for fi, file in enumerate(files):
    preproc_conf.append(np.load(file, allow_pickle=True))
    
preproc_conf_files = '/home/sshankar/raiders/derivatives/sub-01/ses-17/'
files = sorted(glob.glob(preproc_conf_files + confound_pattern))
for fi, file in enumerate(files):
    preproc_conf.append(np.load(file, allow_pickle=True))

# %%
fig, axs = plt.subplots(5, figsize=(15,10), sharex=True, sharey=True)
for c in range(5):
    axs[c].plot(raw_conf[0][:,c], 'r')
    axs[c].plot(preproc_conf[3][:,c], 'g')

# %%
fig, axs = plt.subplots(5, figsize=(15,10), sharex=True, sharey=True)
for c in range(5):
    axs[c].plot(raw_conf[1][:,c], 'r')
    axs[c].plot(preproc_conf[4][:,c], 'g')

# %%
fig, axs = plt.subplots(5, figsize=(15,10), sharex=True, sharey=True)
for c in range(5):
    axs[c].plot(raw_conf[2][:,c], 'r')
    axs[c].plot(preproc_conf[5][:,c], 'g')

# %%
fig, axs = plt.subplots(5, figsize=(15,10), sharex=True, sharey=True)
for c in range(5):
    axs[c].plot(raw_conf[3][:,c], 'r')
    axs[c].plot(preproc_conf[0][:,c], 'g')

# %%
fig, axs = plt.subplots(5, figsize=(15,10), sharex=True, sharey=True)
for c in range(5):
    axs[c].plot(raw_conf[4][:,c], 'r')
    axs[c].plot(preproc_conf[1][:,c], 'g')

# %%
fig, axs = plt.subplots(5, figsize=(15,10), sharex=True, sharey=True)
for c in range(5):
    axs[c].plot(raw_conf[5][:,c], 'r')
    axs[c].plot(preproc_conf[2][:,c], 'g')

# %%
fig, axs = plt.subplots(5, figsize=(15,10), sharex=True, sharey=True)
for c in range(5):
    axs[c].plot(raw_conf[2][:,c], 'r')
    axs[c].plot(preproc_conf[3][:,c], 'g')
